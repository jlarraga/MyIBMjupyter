# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **José Manuel Lárraga Gutiérrez**<br>
# *Assistant Professor*<br>
# *National Institute of Neurology and Neurosurgery*<br>

# %% [markdown]
# *I am interested in data science because I want to understand the insight and trends of cancer treatment*

# %% [markdown]
# ### This code calculates the hypotenuse of a triangle of size *x* and *y*, also proves the triangle inequality

# %%
import math


def hypo(x, y):
    return math.sqrt(x**2+y**2)


hypo(3, 4) <= abs(3) + abs(4)
# Out:
# True

# %% [markdown]
# - The above code is based on the following proof. See the next figure <br>
# ![triangle-inequality.png](attachment:82d1a3ef-4a96-49e8-80c9-b8eec96d530a.png)

# %% [markdown]
# - For more information the reader might consult the following  __[link](https://en.wikipedia.org/wiki/Triangle_inequality)__
